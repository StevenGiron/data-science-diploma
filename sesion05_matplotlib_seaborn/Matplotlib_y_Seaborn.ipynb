# %% [markdown]
# # Librerias de Visualización
# ## Matplotlib
# ### Uso básico

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np

x = np.linspace(0, 10, 100)
print(x) # Inspección de datos
# Out:
# [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
#   7.27272727  7.37373737  7.47474747  7.57575758  7.67676768  7.77777778
# ...

# %%
fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--');

# %% [markdown]
# ### Gráfico de línea y dispersión

# %%
fig = plt.figure()
ax = plt.axes()

# %%
x = np.linspace(0, 10, 1000) # Mil valores lineales del 0 al 10

# %%
plt.plot(x, np.sin(x), linestyle='dashed')
plt.plot(x, np.cos(x));

# %% [markdown]
# ### Histogramas

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/KaitaiD/Man-of-the-Match-FIFA-2018/master/FIFA%202018%20Statistics.csv')
df.columns
# Out:
# Index(['Date', 'Team', 'Opponent', 'Goal Scored', 'Ball Possession %',
#        'Attempts', 'On-Target', 'Off-Target', 'Blocked', 'Corners', 'Offsides',
#        'Free Kicks', 'Saves', 'Pass Accuracy %', 'Passes',
#        'Distance Covered (Kms)', 'Fouls Committed', 'Yellow Card',
#        'Yellow & Red', 'Red', 'Man of the Match', '1st Goal', 'Round', 'PSO',
#        'Goals in PSO', 'Own goals', 'Own goal Time'],
#       dtype='object')

# %%
plt.hist(df['Ball Possession %']);

# %% [markdown]
# ### Leyendas

# %%
plt.hist(df['Ball Possession %'], label=['Posesión']);
plt.legend()

# %%
x = np.linspace(0, 10, 1000)
fig, ax = plt.subplots()
ax.plot(x, np.sin(x), '-b', label='Sine') # Con el parametro label especificamos como queremos que se llamen nuestros datos en gráfica
ax.plot(x, np.cos(x), '--r', label='Cosine')
ax.axis('equal')
leg = ax.legend(loc='upper left', frameon=False)

# %% [markdown]
# ### Subgráficas

# %%
fig = plt.figure()


ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4],
                   xticklabels=[], ylim=(-1.2, 1.2))
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4],
                   ylim=(-1.2, 1.2))

x = np.linspace(0, 10)

ax1.plot(np.sin(x))
ax2.plot(np.cos(x));

# %%
fig4 = plt.figure()

ax1_4 = fig4.add_subplot(2, 2, 1) # first position
ax2_4 = fig4.add_subplot(2, 2, 2) # second position
ax3_4 = fig4.add_subplot(2, 2, 3) # third position

plt.plot(np.random.randn(50).cumsum(), 'k--')

_ = ax1_4.hist(np.random.randn(100), bins=20, color='k', alpha=0.3)

ax2_4.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))

# %%
fig, axes = plt.subplots(2,3)

axes
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %% [markdown]
# #### Ajustando espacio entre gráficas

# %%
# we will make two subplots with the same x- and y-axis 
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.randn(500), bins=50, color='k', alpha=0.5)
plt.subplots_adjust(wspace=0, hspace=0)
plt.show()

# we will make two subplots with the same x- and y-axis 
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.randn(500), bins=50, color='k', alpha=0.5)
plt.subplots_adjust(wspace=1, hspace=1)

# %% [markdown]
# ### Colores, marcadores y estilos de linea
# Cada subgráfica de Matplotlib acepta arreglos de coordenadas Y y X y opcionalmente un string de abreviacion para el color y estilo de la linea.
# Ej:
#
# `ax.plot(x, y, 'g--')`
#
# Así construimos una gráfica de X vs Y con linea punteada verde. Esta es una sintaxis alternativa:
#
# `ax.plot(x, y, linestyle='--', color='g')`

# %%
import numpy as np

plt.plot(np.random.randn(30).cumsum(), color='k', linestyle='--', marker='o')

# %% [markdown]
# ### Ubicación de linea
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

figure = plt.figure()

data = np.random.randn(30).cumsum()
plt.plot(data, 'k--', label='Default')
plt.plot(data, 'k-', drawstyle='steps-post', label='steps-post')

# figure.legend(loc='best')
figure.suptitle("Post")
# Out:
# Text(0.5, 0.98, 'Post')

# %%
import numpy as np

figure = plt.figure()

data = np.random.randn(30).cumsum()
plt.plot(data, 'k--', label='Default')
plt.plot(data, 'k-', drawstyle='steps-pre', label='steps-pre')

figure.legend(loc='best')
figure.suptitle("Pre")

# %% [markdown]
# ### Personalizar ejes

# %%
fig = plt.figure()

ax = fig.add_subplot(1, 1, 1)

# Configuración por defecto
ax.plot(np.random.randn(1000).cumsum())

# %%
fig = plt.figure()

ax = fig.add_subplot(1, 1, 1)

ax.plot(np.random.randn(1000).cumsum())

ticks = ax.set_xticks([0, 250, 500, 750, 1000])
# The rotation option sets the x tick labels at a 30-degree rotation.
labels = ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'], rotation=30, fontsize='small')

ax.set_title('My first matplotlib plot')
ax.set_xlabel('Stages')

# %% [markdown]
# ## Seaborn

# %%
import seaborn as sns

# %% [markdown]
# ### Diferencia con Matplotlib

# %%
# Matplotlib
rng = np.random.RandomState(0)
x = np.linspace(0, 10, 500)
y = np.cumsum(rng.randn(500, 6), 0)

plt.plot(x, y)
plt.legend('ABCDEF', ncol=2, loc='upper left');

# %%
sns.set()


# el mismo plot que más arriba pero con seaborn
plt.plot(x, y)
plt.legend('ABCDEF', ncol=2, loc='upper left');

# %% [markdown]
# ### Histogramas (seaborn)

# %%
plt.hist(df['Ball Possession %'])
# Out:
# (array([ 3.,  6., 11., 24., 19., 20., 21., 14.,  5.,  5.]),
#  array([25., 30., 35., 40., 45., 50., 55., 60., 65., 70., 75.]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(df['Ball Possession %'])
# Out:
# A:\Programar\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Ball Possession %', ylabel='Density'>

# %%
sns.distplot(df[df.Team == 'Russia']['Goal Scored'])
sns.distplot(df[df.Team == 'Brazil']['Goal Scored'])
# Out:
# A:\Programar\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# A:\Programar\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Goal Scored', ylabel='Density'>

# %%
data = np.random.multivariate_normal([0, 0], [[5, 2], [2, 2]], size=2000)
data = pd.DataFrame(data, columns=['x', 'y'])
sns.distplot(data['x'])
sns.distplot(data['y']);
# Out:
# A:\Programar\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# A:\Programar\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Pairplots

# %%
iris = sns.load_dataset("iris")
print(iris.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris, hue='species', size=2.5);
# Out:
# A:\Programar\Anaconda\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %% [markdown]
# Si hay mucha correlacion entre dos variables se puede llgar a borrar una para no ser redundantes

# %%
sns.set_theme(style="ticks", palette="pastel")

# Load the example tips dataset
tips = sns.load_dataset("tips")

# Draw a nested boxplot to show bills by day and time
sns.boxplot(x="day", y="total_bill",
            hue="smoker", palette=["m", "g"],
            data=tips)
sns.despine(offset=10, trim=True)

# %%
sns.color_palette()
